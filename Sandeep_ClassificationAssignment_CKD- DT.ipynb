# %%
#importing required libraries and functions
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

dataset=pd.read_csv("CKD.csv")
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]

# %%
dataset.shape
# Out:
# (399, 25)

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
#to manage nominal data we use one hot encoding
dataset=pd.get_dummies(dataset)

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_a', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_abnormal',
#        'rbc_normal', 'pc_abnormal', 'pc_normal', 'pcc_notpresent',
#        'pcc_present', 'ba_notpresent', 'ba_present', 'htn_no', 'htn_yes',
#        'dm_no', 'dm_yes', 'cad_no', 'cad_yes', 'appet_poor', 'appet_yes',
#        'pe_poor', 'pe_yes', 'ane_no', 'ane_yes', 'classification_no',
#        'classification_yes'],
#       dtype='object')

# %%
# considering data whic is yes, normal, present

idp=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv','wc', 'rc', 'sg_a', 'sg_b', 'sg_c', 'sg_d','rbc_normal', 'pc_normal','pcc_present','ba_present','htn_yes','dm_yes','cad_yes','appet_yes','pe_yes', 'ane_yes']]
dp=dataset[['classification_yes']]

# %%
dataset['classification_yes'].value_counts()
# Out:
# 1    249
# 0    150
# Name: classification_yes, dtype: int64

# %%
#Split Data
x_train,x_test,y_train,y_test=train_test_split(idp,dp,test_size=0.30,random_state=0)
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
param_grid= {'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]}
grid=GridSearchCV(DecisionTreeClassifier(),param_grid,refit=True,verbose=3,n_jobs=1,scoring="f1_weighted")
grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] max_depth=None, min_samples_split=2 .............................
# [CV] . max_depth=None, min_samples_split=2, score=0.935, total=   0.0s
# [CV] max_depth=None, min_samples_split=2 .............................
# [CV] . max_depth=None, min_samples_split=2, score=0.936, total=   0.0s
# [CV] max_depth=None, min_samples_split=2 .............................
# [CV] . max_depth=None, min_samples_split=2, score=0.978, total=   0.0s
# [CV] max_depth=None, min_samples_split=5 .............................
# [CV] . max_depth=None, min_samples_split=5, score=0.935, total=   0.0s
# [CV] max_depth=None, min_samples_split=5 .............................
# [CV] . max_depth=None, min_samples_split=5, score=0.936, total=   0.0s
# [CV] max_depth=None, min_samples_split=5 .............................
# [CV] . max_depth=None, min_samples_split=5, score=0.978, total=   0.0s
# [CV] max_depth=None, min_samples_split=10 ............................
# [CV]  max_depth=None, min_samples_split=10, score=0.935, total=   0.0s
# [CV] max_depth=None, min_samples_split=10 ............................
# [CV]  max_depth=None, min_samples_split=10, score=0.936, total=   0.0s
# [CV] max_depth=None, min_samples_split=10 ............................
# [CV]  max_depth=None, min_samples_split=10, score=0.978, total=   0.0s
# [CV] max_depth=5, min_samples_split=2 ................................
# [CV] .... max_depth=5, min_samples_split=2, score=0.925, total=   0.0s
# [CV] max_depth=5, min_samples_split=2 ................................
# [CV] .... max_depth=5, min_samples_split=2, score=0.936, total=   0.0s
# [CV] max_depth=5, min_samples_split=2 ................................
# [CV] .... max_depth=5, min_samples_split=2, score=0.978, total=   0.0s
# [CV] max_depth=5, min_samples_split=5 ................................
# [CV] .... max_depth=5, min_samples_split=5, score=0.935, total=   0.0s
# [CV] max_depth=5, min_samples_split=5 ................................
# [CV] .... max_depth=5, min_samples_split=5, score=0.936, total=   0.0s
# [CV] max_depth=5, min_samples_split=5 ................................
# [CV] .... max_depth=5, min_samples_split=5, score=0.978, total=   0.0s
# [CV] max_depth=5, min_samples_split=10 ...............................
# [CV] ... max_depth=5, min_samples_split=10, score=0.946, total=   0.0s
# [CV] max_depth=5, min_samples_split=10 ...............................
# [CV] ... max_depth=5, min_samples_split=10, score=0.936, total=   0.0s
# [CV] max_depth=5, min_samples_split=10 ...............................
# [CV] ... max_depth=5, min_samples_split=10, score=0.978, total=   0.0s
# [CV] max_depth=10, min_samples_split=2 ...............................
# [CV] ... max_depth=10, min_samples_split=2, score=0.935, total=   0.0s
# [CV] max_depth=10, min_samples_split=2 ...............................
# [CV] ... max_depth=10, min_samples_split=2, score=0.936, total=   0.0s
# [CV] max_depth=10, min_samples_split=2 ...............................
# [CV] ... max_depth=10, min_samples_split=2, score=0.956, total=   0.0s
# [CV] max_depth=10, min_samples_split=5 ...............................
# [CV] ... max_depth=10, min_samples_split=5, score=0.935, total=   0.0s
# [CV] max_depth=10, min_samples_split=5 ...............................
# [CV] ... max_depth=10, min_samples_split=5, score=0.936, total=   0.0s
# [CV] max_depth=10, min_samples_split=5 ...............................
# [CV] ... max_depth=10, min_samples_split=5, score=0.956, total=   0.0s
# [CV] max_depth=10, min_samples_split=10 ..............................
# [CV] .. max_depth=10, min_samples_split=10, score=0.935, total=   0.0s
# [CV] max_depth=10, min_samples_split=10 ..............................
# [CV] .. max_depth=10, min_samples_split=10, score=0.936, total=   0.0s
# [CV] max_depth=10, min_samples_split=10 ..............................
# [CV] .. max_depth=10, min_samples_split=10, score=0.978, total=   0.0s
# C:\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    0.0s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort=False, random_state=None,
#                                               splitter='best'),
#              iid='warn', n_jobs=1,
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_split': [2, 5, 10]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_weighted', verbose=3)

# %%
DecisionTreeClassifier().get_params().keys()
# Out:
# dict_keys(['class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'presort', 'random_state', 'splitter'])

# %%
pd.DataFrame(grid.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.004283      0.000462         0.001862    2.114892e-04
# 1       0.001994      0.000001         0.000997    0.000000e+00
# 2       0.002326      0.000469         0.001001    5.844363e-06
# 3       0.002817      0.000247         0.000332    4.701340e-04
# 4       0.002161      0.000622         0.000997    2.973602e-07
# 5       0.001999      0.000006         0.000998    1.946680e-07
# 6       0.002126      0.000661         0.000996    1.520405e-06
# 7       0.002326      0.000469         0.001331    4.709208e-04
# 8       0.001845      0.000159         0.000998    2.973602e-07
#
#   param_max_depth param_min_samples_split  \
# 0            None                       2
# 1            None                       5
# 2            None                      10
# 3               5                       2
# 4               5                       5
# 5               5                      10
# 6              10                       2
# 7              10                       5
# 8              10                      10
#
#                                          params  split0_test_score  \
# 0   {'max_depth': None, 'min_samples_split': 2}           0.935484
# 1   {'max_depth': None, 'min_samples_split': 5}           0.935484
# 2  {'max_depth': None, 'min_samples_split': 10}           0.935082
# 3      {'max_depth': 5, 'min_samples_split': 2}           0.924934
# 4      {'max_depth': 5, 'min_samples_split': 5}           0.935484
# 5     {'max_depth': 5, 'min_samples_split': 10}           0.945711
# 6     {'max_depth': 10, 'min_samples_split': 2}           0.935484
# 7     {'max_depth': 10, 'min_samples_split': 5}           0.935484
# 8    {'max_depth': 10, 'min_samples_split': 10}           0.935082
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.936271           0.978361         0.950039        0.020029
# 1           0.936271           0.978361         0.950039        0.020029
# 2           0.936271           0.978361         0.949904        0.020127
# 3           0.936271           0.978361         0.946522        0.022984
# 4           0.936271           0.978361         0.950039        0.020029
# 5           0.936271           0.978361         0.953447        0.018033
# 6           0.936271           0.956403         0.942719        0.009681
# 7           0.936271           0.956403         0.942719        0.009681
# 8           0.936271           0.978361         0.949904        0.020127
#
#    rank_test_score
# 0                2
# 1                2
# 2                5
# 3                7
# 4                2
# 5                1
# 6                8
# 7                8
# 8                5

# %%
y_pred=grid.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
clf_report=classification_report(y_test,y_pred)

# %%
print(clf_report)
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.98      0.89        45
#            1       0.98      0.87      0.92        75
#
#     accuracy                           0.91       120
#    macro avg       0.90      0.92      0.91       120
# weighted avg       0.92      0.91      0.91       120
#
# [[44  1]
#  [10 65]]

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
# Out:
# 0.9222222222222223
