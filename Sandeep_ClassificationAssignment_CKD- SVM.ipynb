# %%
#importing required libraries and functions
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

dataset=pd.read_csv("CKD.csv")
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]

# %%
dataset.shape
# Out:
# (399, 25)

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
#to manage nominal data we use one hot encoding
dataset=pd.get_dummies(dataset)

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_a', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_abnormal',
#        'rbc_normal', 'pc_abnormal', 'pc_normal', 'pcc_notpresent',
#        'pcc_present', 'ba_notpresent', 'ba_present', 'htn_no', 'htn_yes',
#        'dm_no', 'dm_yes', 'cad_no', 'cad_yes', 'appet_poor', 'appet_yes',
#        'pe_poor', 'pe_yes', 'ane_no', 'ane_yes', 'classification_no',
#        'classification_yes'],
#       dtype='object')

# %%
# considering data whic is yes, normal, present

idp=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv','wc', 'rc', 'sg_a', 'sg_b', 'sg_c', 'sg_d','rbc_normal', 'pc_normal','pcc_present','ba_present','htn_yes','dm_yes','cad_yes','appet_yes','pe_yes', 'ane_yes']]
dp=dataset[['classification_yes']]

# %%
dataset['classification_yes'].value_counts()
# Out:
# 1    249
# 0    150
# Name: classification_yes, dtype: int64

# %%
#Split Data
x_train,x_test,y_train,y_test=train_test_split(idp,dp,test_size=0.30,random_state=0)
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid= {'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']}
grid=GridSearchCV(SVC(probability=True),param_grid,refit=True,verbose=3,n_jobs=1,scoring="f1_weighted")
grid.fit(x_train,y_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] C=0.1, gamma=scale, kernel=linear ...............................
# [CV] ... C=0.1, gamma=scale, kernel=linear, score=0.979, total=   0.0s
# [CV] C=0.1, gamma=scale, kernel=linear ...............................
# [CV] ... C=0.1, gamma=scale, kernel=linear, score=0.968, total=   0.0s
# [CV] C=0.1, gamma=scale, kernel=linear ...............................
# [CV] ... C=0.1, gamma=scale, kernel=linear, score=0.979, total=   0.0s
# [CV] C=0.1, gamma=scale, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=scale, kernel=rbf, score=0.968, total=   0.0s
# [CV] C=0.1, gamma=scale, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=scale, kernel=rbf, score=0.968, total=   0.0s
# [CV] C=0.1, gamma=scale, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=scale, kernel=rbf, score=0.989, total=   0.0s
# [CV] C=0.1, gamma=auto, kernel=linear ................................
# [CV] .... C=0.1, gamma=auto, kernel=linear, score=0.979, total=   0.0s
# [CV] C=0.1, gamma=auto, kernel=linear ................................
# [CV] .... C=0.1, gamma=auto, kernel=linear, score=0.968, total=   0.0s
# [CV] C=0.1, gamma=auto, kernel=linear ................................
# [CV] .... C=0.1, gamma=auto, kernel=linear, score=0.979, total=   0.0s
# [CV] C=0.1, gamma=auto, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=auto, kernel=rbf, score=0.968, total=   0.0s
# [CV] C=0.1, gamma=auto, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=auto, kernel=rbf, score=0.968, total=   0.0s
# [CV] C=0.1, gamma=auto, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=auto, kernel=rbf, score=0.989, total=   0.0s
# [CV] C=1, gamma=scale, kernel=linear .................................
# [CV] ..... C=1, gamma=scale, kernel=linear, score=0.968, total=   0.0s
# [CV] C=1, gamma=scale, kernel=linear .................................
# [CV] ..... C=1, gamma=scale, kernel=linear, score=0.989, total=   0.0s
# [CV] C=1, gamma=scale, kernel=linear .................................
# [CV] ..... C=1, gamma=scale, kernel=linear, score=0.989, total=   0.0s
# [CV] C=1, gamma=scale, kernel=rbf ....................................
# [CV] ........ C=1, gamma=scale, kernel=rbf, score=0.989, total=   0.0s
# [CV] C=1, gamma=scale, kernel=rbf ....................................
# [CV] ........ C=1, gamma=scale, kernel=rbf, score=0.978, total=   0.0s
# [CV] C=1, gamma=scale, kernel=rbf ....................................
# [CV] ........ C=1, gamma=scale, kernel=rbf, score=0.989, total=   0.0s
# [CV] C=1, gamma=auto, kernel=linear ..................................
# [CV] ...... C=1, gamma=auto, kernel=linear, score=0.968, total=   0.0s
# [CV] C=1, gamma=auto, kernel=linear ..................................
# [CV] ...... C=1, gamma=auto, kernel=linear, score=0.989, total=   0.0s
# [CV] C=1, gamma=auto, kernel=linear ..................................
# [CV] ...... C=1, gamma=auto, kernel=linear, score=0.989, total=   0.0s
# [CV] C=1, gamma=auto, kernel=rbf .....................................
# [CV] ......... C=1, gamma=auto, kernel=rbf, score=0.989, total=   0.0s
# [CV] C=1, gamma=auto, kernel=rbf .....................................
# [CV] ......... C=1, gamma=auto, kernel=rbf, score=0.978, total=   0.0s
# [CV] C=1, gamma=auto, kernel=rbf .....................................
# [CV] ......... C=1, gamma=auto, kernel=rbf, score=0.989, total=   0.0s
# [CV] C=10, gamma=scale, kernel=linear ................................
# [CV] .... C=10, gamma=scale, kernel=linear, score=0.989, total=   0.0s
# [CV] C=10, gamma=scale, kernel=linear ................................
# [CV] .... C=10, gamma=scale, kernel=linear, score=0.979, total=   0.0s
# [CV] C=10, gamma=scale, kernel=linear ................................
# [CV] .... C=10, gamma=scale, kernel=linear, score=0.978, total=   0.0s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] ....... C=10, gamma=scale, kernel=rbf, score=0.979, total=   0.0s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] ....... C=10, gamma=scale, kernel=rbf, score=0.989, total=   0.0s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] ....... C=10, gamma=scale, kernel=rbf, score=0.989, total=   0.0s
# [CV] C=10, gamma=auto, kernel=linear .................................
# [CV] ..... C=10, gamma=auto, kernel=linear, score=0.989, total=   0.0s
# [CV] C=10, gamma=auto, kernel=linear .................................
# [CV] ..... C=10, gamma=auto, kernel=linear, score=0.979, total=   0.0s
# [CV] C=10, gamma=auto, kernel=linear .................................
# [CV] ..... C=10, gamma=auto, kernel=linear, score=0.978, total=   0.0s
# [CV] C=10, gamma=auto, kernel=rbf ....................................
# [CV] ........ C=10, gamma=auto, kernel=rbf, score=0.979, total=   0.0s
# [CV] C=10, gamma=auto, kernel=rbf ....................................
# [CV] ........ C=10, gamma=auto, kernel=rbf, score=0.989, total=   0.0s
# [CV] C=10, gamma=auto, kernel=rbf ....................................
# [CV] ........ C=10, gamma=auto, kernel=rbf, score=0.989, total=   0.0s
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:    0.2s finished
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='rbf', max_iter=-1,
#                            probability=True, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='warn', n_jobs=1,
#              param_grid={'C': [0.1, 1, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_weighted', verbose=3)

# %%
SVC().get_params().keys()
# Out:
# dict_keys(['C', 'cache_size', 'class_weight', 'coef0', 'decision_function_shape', 'degree', 'gamma', 'kernel', 'max_iter', 'probability', 'random_state', 'shrinking', 'tol', 'verbose'])

# %%
pd.DataFrame(grid.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.018577      0.020652         0.001330    4.689540e-04     0.1
# 1        0.008643      0.000471         0.001330    4.699655e-04     0.1
# 2        0.003748      0.000340         0.000792    5.814575e-04     0.1
# 3        0.008310      0.000470         0.001662    4.701903e-04     0.1
# 4        0.002992      0.000000         0.000998    1.123916e-07       1
# 5        0.004654      0.000470         0.000998    1.946680e-07       1
# 6        0.003989      0.001411         0.001330    4.704150e-04       1
# 7        0.005865      0.000092         0.001702    5.002111e-04       1
# 8        0.004314      0.000475         0.001331    4.702474e-04      10
# 9        0.003325      0.000471         0.001330    4.703026e-04      10
# 10       0.002659      0.000470         0.000998    2.973602e-07      10
# 11       0.002984      0.000010         0.000998    1.123916e-07      10
#
#    param_gamma param_kernel                                            params  \
# 0        scale       linear  {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 1        scale          rbf     {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# 2         auto       linear   {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}
# 3         auto          rbf      {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}
# 4        scale       linear    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 5        scale          rbf       {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 6         auto       linear     {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 7         auto          rbf        {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 8        scale       linear   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 9        scale          rbf      {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 10        auto       linear    {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 11        auto          rbf       {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0            0.978605           0.967829           0.978605         0.975013
# 1            0.967977           0.967829           0.989276         0.975027
# 2            0.978605           0.967829           0.978605         0.975013
# 3            0.967977           0.967829           0.989276         0.975027
# 4            0.967977           0.989276           0.989215         0.982156
# 5            0.989276           0.978495           0.989276         0.985682
# 6            0.967977           0.989276           0.989215         0.982156
# 7            0.989276           0.978495           0.989276         0.985682
# 8            0.989276           0.978605           0.978495         0.982125
# 9            0.978605           0.989215           0.989215         0.985678
# 10           0.989276           0.978605           0.978495         0.982125
# 11           0.978605           0.989215           0.989215         0.985678
#
#     std_test_score  rank_test_score
# 0         0.005080               11
# 1         0.010076                9
# 2         0.005080               11
# 3         0.010076                9
# 4         0.010026                5
# 5         0.005083                1
# 6         0.010026                5
# 7         0.005083                1
# 8         0.005057                7
# 9         0.005002                3
# 10        0.005057                7
# 11        0.005002                3

# %%
y_pred=grid.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
clf_report=classification_report(y_test,y_pred)

# %%
print(clf_report)
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        45
#            1       1.00      0.96      0.98        75
#
#     accuracy                           0.97       120
#    macro avg       0.97      0.98      0.97       120
# weighted avg       0.98      0.97      0.98       120
#
# [[45  0]
#  [ 3 72]]

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
# Out:
# 1.0
